# %%
# import cv2
# import numpy as np

# # Đường dẫn đến file mô hình và cấu hình
# MODEL_PATH = "MobileNetSSD_deploy.caffemodel"
# CONFIG_PATH = "MobileNetSSD_deploy.prototxt"
# LABELS_PATH = "labels.txt"

# # Danh sách nhãn của các đối tượng
# CLASSES = []
# with open(LABELS_PATH, 'r') as f:
#     CLASSES = [line.strip() for line in f.readlines()]

# # Tải mô hình MobileNet SSD
# net = cv2.dnn.readNetFromCaffe(CONFIG_PATH, MODEL_PATH)

# # Khởi tạo webcam
# cap = cv2.VideoCapture(0)
# cap.set(cv2.CAP_PROP_FRAME_WIDTH, 720)  # Giảm độ phân giải để tăng tốc
# cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break

#     # Chuẩn bị frame cho mô hình
#     (h, w) = frame.shape[:2]
#     blob = cv2.dnn.blobFromImage(frame, 0.007843, (300, 300), 127.5)

#     # Đưa blob vào mô hình
#     net.setInput(blob)
#     detections = net.forward()

#     # Xử lý kết quả nhận diện
#     for i in range(detections.shape[2]):
#         confidence = detections[0, 0, i, 2]
#         if confidence > 0.5:  # Ngưỡng tin cậy
#             idx = int(detections[0, 0, i, 1])
#             box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
#             (startX, startY, endX, endY) = box.astype("int")

#             # Vẽ hộp và nhãn
#             label = f"{CLASSES[idx]}: {confidence:.2f}"
#             cv2.rectangle(frame, (startX, startY), (endX, endY), (0, 255, 0), 2)
#             cv2.putText(frame, label, (startX, startY - 10),
#                         cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

#     # Hiển thị frame
#     cv2.imshow("Object Detection", frame)

#     # Nhấn 'q' để thoát
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# # Giải phóng tài nguyên
# cap.release()
# cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import time
from datetime import datetime
import logging
from scipy.spatial import distance

# Cấu hình logging
logging.basicConfig(filename='object_detection.log', level=logging.INFO,
                    format='%(asctime)s - %(message)s')

# Đường dẫn đến file mô hình và cấu hình
MODEL_PATH = "MobileNetSSD_deploy.caffemodel"
CONFIG_PATH = "MobileNetSSD_deploy.prototxt"
LABELS_PATH = "labels.txt"

# Danh sách nhãn của các đối tượng
CLASSES = []
with open(LABELS_PATH, 'r') as f:
    CLASSES = [line.strip() for line in f.readlines()]

# Tải mô hình MobileNet SSD
net = cv2.dnn.readNetFromCaffe(CONFIG_PATH, MODEL_PATH)

# Khởi tạo webcam
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 720)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

# Biến để theo dõi đối tượng và log
tracked_objects = {}  # Lưu trữ đối tượng: {id: {'class', 'center', 'box', 'confidence'}}
next_id = 0  # ID tiếp theo để gán cho đối tượng mới
last_log_time = time.time()  # Thời gian log định kỳ cuối cùng
LOG_INTERVAL = 10  # Ghi log mỗi 10 giây
MOVE_THRESHOLD = 360  # Ngưỡng di chuyển (nửa màn hình: 720/2 = 360 pixel)
FRAME_WIDTH = 720  # Chiều rộng khung hình

def assign_objects(current_objects):
    global next_id, tracked_objects
    new_tracked_objects = {}
    used_ids = set()

    # Gán đối tượng hiện tại cho các đối tượng đã theo dõi
    for curr_obj in current_objects:
        curr_center = curr_obj['center']
        min_dist = float('inf')
        matched_id = None

        # Tìm đối tượng trước đó gần nhất
        for obj_id, prev_obj in tracked_objects.items():
            if obj_id in used_ids:
                continue
            dist = distance.euclidean(curr_center, prev_obj['center'])
            if dist < min_dist and dist < 100:  # Ngưỡng khoảng cách để gán cùng đối tượng
                min_dist = dist
                matched_id = obj_id

        # Nếu tìm thấy đối tượng khớp
        if matched_id is not None:
            new_tracked_objects[matched_id] = curr_obj
            used_ids.add(matched_id)
            # Kiểm tra di chuyển đáng kể
            prev_center = tracked_objects[matched_id]['center']
            move_dist = distance.euclidean(curr_center, prev_center)
            if move_dist > MOVE_THRESHOLD:
                logging.info(f"Object {matched_id} ({curr_obj['class']}) moved significantly: "
                             f"{move_dist:.2f} pixels")
                print(f"Object {matched_id} ({curr_obj['class']}) moved {move_dist:.2f} pixels")
        else:
            # Gán ID mới cho đối tượng mới
            new_tracked_objects[next_id] = curr_obj
            logging.info(f"New object detected: ID {next_id}, Class: {curr_obj['class']}, "
                         f"Confidence: {curr_obj['confidence']:.2f}, Center: {curr_obj['center']}")
            print(f"New object: ID {next_id}, Class: {curr_obj['class']}")
            next_id += 1

    # Kiểm tra đối tượng biến mất
    for obj_id, prev_obj in tracked_objects.items():
        if obj_id not in new_tracked_objects:
            logging.info(f"Object {obj_id} ({prev_obj['class']}) disappeared")
            print(f"Object {obj_id} ({prev_obj['class']}) disappeared")

    tracked_objects = new_tracked_objects

def log_periodic():
    """Ghi log định kỳ trạng thái hiện tại"""
    log_message = f"Periodic log: {len(tracked_objects)} objects detected"
    for obj_id, obj in tracked_objects.items():
        log_message += f"\n- ID {obj_id}: {obj['class']}, Confidence: {obj['confidence']:.2f}, " \
                       f"Center: {obj['center']}"
    logging.info(log_message)
    print("\n=== Periodic Log ===")
    print(log_message)

frame_count = 0
start_time = time.time()

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # Chuẩn bị frame cho mô hình
    (h, w) = frame.shape[:2]
    blob = cv2.dnn.blobFromImage(frame, 0.007843, (300, 300), 127.5)

    # Đưa blob vào mô hình
    net.setInput(blob)
    detections = net.forward()

    # Lưu danh sách đối tượng hiện tại
    current_objects = []
    for i in range(detections.shape[2]):
        confidence = detections[0, 0, i, 2]
        if confidence > 0.5:  # Ngưỡng tin cậy
            idx = int(detections[0, 0, i, 1])
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            # Tính trung tâm và kích thước
            center_x = (startX + endX) // 2
            center_y = (startY + endY) // 2
            box_width = endX - startX
            box_height = endY - startY

            # Lưu thông tin đối tượng
            obj_info = {
                'class': CLASSES[idx],
                'confidence': confidence,
                'center': (center_x, center_y),
                'box': (startX, startY, endX, endY),
                'size': (box_width, box_height)
            }
            current_objects.append(obj_info)

            # Vẽ hộp và nhãn
            label = f"{CLASSES[idx]}: {confidence:.2f}"
            cv2.rectangle(frame, (startX, startY), (endX, endY), (0, 255, 0), 2)
            cv2.putText(frame, label, (startX, startY - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Gán và theo dõi đối tượng
    assign_objects(current_objects)

    # Kiểm tra log định kỳ (mỗi 10 giây)
    current_time = time.time()
    if current_time - last_log_time >= LOG_INTERVAL:
        log_periodic()
        last_log_time = current_time

    # Tính FPS
    frame_count += 1
    elapsed_time = current_time - start_time
    fps = frame_count / elapsed_time if elapsed_time > 0 else 0

    # Hiển thị FPS trên frame
    cv2.putText(frame, f"FPS: {fps:.2f}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    # Hiển thị frame
    cv2.imshow("Object Detection", frame)

    # Nhấn 'q' để thoát
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Giải phóng tài nguyên
cap.release()
cv2.destroyAllWindows()
# Out:
# New object: ID 0, Class: person
# New object: ID 1, Class: person
# New object: ID 2, Class: person
# Object 2 (person) disappeared
# New object: ID 3, Class: person
# Object 3 (person) disappeared
# Object 0 (person) disappeared
# New object: ID 4, Class: person
# Object 4 (person) disappeared
# New object: ID 5, Class: person
# New object: ID 6, Class: person
# Object 6 (person) disappeared
# New object: ID 7, Class: chair
# Object 7 (chair) disappeared
# New object: ID 8, Class: chair
# Object 8 (chair) disappeared
# New object: ID 9, Class: chair
# Object 9 (chair) disappeared
# New object: ID 10, Class: bottle
# Object 10 (bottle) disappeared
# New object: ID 11, Class: bottle
# Object 11 (bottle) disappeared
# New object: ID 12, Class: person
# Object 5 (person) disappeared
# New object: ID 13, Class: person
# Object 12 (person) disappeared
# New object: ID 14, Class: person
# Object 13 (person) disappeared
# New object: ID 15, Class: person
# Object 14 (person) disappeared
# New object: ID 16, Class: person
# Object 16 (person) disappeared
# New object: ID 17, Class: person
# Object 17 (person) disappeared
# Object 15 (person) disappeared
# New object: ID 18, Class: person
# Object 1 (person) disappeared
# New object: ID 19, Class: person
# Object 18 (person) disappeared
# New object: ID 20, Class: person
# New object: ID 21, Class: person
# Object 20 (person) disappeared
# Object 21 (person) disappeared
# New object: ID 22, Class: person
# New object: ID 23, Class: person
# Object 23 (person) disappeared
# Object 22 (person) disappeared
# New object: ID 24, Class: person
# New object: ID 25, Class: person
# Object 25 (person) disappeared
# New object: ID 26, Class: person
# Object 24 (person) disappeared
# New object: ID 27, Class: person
# Object 27 (person) disappeared
# New object: ID 28, Class: person
# Object 26 (person) disappeared
# Object 28 (person) disappeared
# New object: ID 29, Class: person
# Object 29 (person) disappeared
# Object 19 (bottle) disappeared
# New object: ID 30, Class: person
# New object: ID 31, Class: person
# Object 31 (person) disappeared
# New object: ID 32, Class: person
# Object 32 (person) disappeared
# New object: ID 33, Class: person
# New object: ID 34, Class: bottle
# Object 34 (bottle) disappeared
# Object 33 (person) disappeared
# New object: ID 35, Class: person
# Object 35 (person) disappeared
#
# === Periodic Log ===
# Periodic log: 1 objects detected
# - ID 30: person, Confidence: 0.89, Center: (182, 312)
# New object: ID 36, Class: person
# Object 36 (person) disappeared
# New object: ID 37, Class: person
# Object 37 (person) disappeared
# New object: ID 38, Class: bottle
# Object 38 (bottle) disappeared
# New object: ID 39, Class: bottle
# Object 39 (bottle) disappeared
# New object: ID 40, Class: bottle
# Object 40 (bottle) disappeared
# New object: ID 41, Class: bottle
# Object 41 (bottle) disappeared
# New object: ID 42, Class: bottle
# Object 42 (bottle) disappeared
# New object: ID 43, Class: bottle
# Object 43 (bottle) disappeared
# New object: ID 44, Class: bottle
# Object 44 (bottle) disappeared
# New object: ID 45, Class: person
# Object 45 (person) disappeared
# New object: ID 46, Class: bottle
# Object 46 (bottle) disappeared
# New object: ID 47, Class: person
# Object 47 (person) disappeared
# New object: ID 48, Class: person
# Object 48 (person) disappeared
# New object: ID 49, Class: person
# Object 49 (person) disappeared
# New object: ID 50, Class: person
# New object: ID 51, Class: person
# New object: ID 52, Class: person
# Object 52 (person) disappeared
# New object: ID 53, Class: person
# Object 53 (person) disappeared
# Object 50 (person) disappeared
# New object: ID 54, Class: person
# Object 54 (person) disappeared
# New object: ID 55, Class: person
# Object 55 (person) disappeared
# New object: ID 56, Class: person
# New object: ID 57, Class: person
# Object 56 (person) disappeared
# New object: ID 58, Class: person
# Object 51 (person) disappeared
# Object 58 (person) disappeared
# New object: ID 59, Class: person
# New object: ID 60, Class: person
# Object 59 (person) disappeared
# Object 60 (person) disappeared
# New object: ID 61, Class: person
# Object 61 (person) disappeared
# New object: ID 62, Class: person
# Object 62 (person) disappeared
# New object: ID 63, Class: person
# Object 63 (person) disappeared
# New object: ID 64, Class: person
# Object 64 (person) disappeared
# Object 57 (person) disappeared
# New object: ID 65, Class: person
# Object 30 (person) disappeared
# Object 65 (person) disappeared
# New object: ID 66, Class: sofa
# Object 66 (sofa) disappeared
# New object: ID 67, Class: cat
# Object 67 (sofa) disappeared
# New object: ID 68, Class: person
# Object 68 (person) disappeared
#
# === Periodic Log ===
# Periodic log: 0 objects detected
# New object: ID 69, Class: person
# Object 69 (person) disappeared
# New object: ID 70, Class: person
# New object: ID 71, Class: person
# Object 70 (person) disappeared
# New object: ID 72, Class: person
# Object 71 (person) disappeared
# New object: ID 73, Class: person
# Object 73 (person) disappeared
# Object 72 (person) disappeared
# New object: ID 74, Class: sofa
# New object: ID 75, Class: sofa
# Object 75 (sofa) disappeared
# New object: ID 76, Class: chair
# Object 76 (chair) disappeared
# New object: ID 77, Class: sofa
# Object 74 (chair) disappeared
# New object: ID 78, Class: chair
# Object 78 (chair) disappeared
# New object: ID 79, Class: chair
# Object 79 (chair) disappeared
# New object: ID 80, Class: sofa
# Object 77 (chair) disappeared
# New object: ID 81, Class: sofa
# Object 81 (sofa) disappeared
# New object: ID 82, Class: chair
# Object 82 (chair) disappeared
# New object: ID 83, Class: sofa
# Object 83 (sofa) disappeared
#
# === Periodic Log ===
# Periodic log: 1 objects detected
# - ID 80: sofa, Confidence: 0.86, Center: (328, 264)
# Object 80 (sofa) disappeared
# New object: ID 84, Class: sofa
# New object: ID 85, Class: person
# Object 84 (chair) disappeared
# New object: ID 86, Class: chair
# Object 86 (chair) disappeared
# New object: ID 87, Class: person
# Object 87 (person) disappeared
# New object: ID 88, Class: person
# Object 85 (person) disappeared
# New object: ID 89, Class: person
# Object 88 (person) disappeared
# New object: ID 90, Class: person
# Object 90 (person) disappeared
# New object: ID 91, Class: person
# Object 89 (person) disappeared
# Object 91 (person) disappeared
# New object: ID 92, Class: person
# Object 92 (person) disappeared
# New object: ID 93, Class: sofa
# Object 93 (sofa) disappeared
# New object: ID 94, Class: sofa
# Object 94 (person) disappeared
# New object: ID 95, Class: sofa
# New object: ID 96, Class: person
# Object 95 (person) disappeared
# Object 96 (sofa) disappeared
# New object: ID 97, Class: sofa
# Object 97 (sofa) disappeared
# New object: ID 98, Class: sofa
# Object 98 (sofa) disappeared
# New object: ID 99, Class: sofa
# New object: ID 100, Class: chair
# Object 99 (sofa) disappeared
# New object: ID 101, Class: person
# Object 100 (chair) disappeared
# New object: ID 102, Class: person
# Object 101 (person) disappeared
# New object: ID 103, Class: person
# Object 103 (person) disappeared
# New object: ID 104, Class: person
# New object: ID 105, Class: person
# Object 105 (person) disappeared
# New object: ID 106, Class: person
# Object 102 (person) disappeared
# Object 104 (person) disappeared
# New object: ID 107, Class: person
# New object: ID 108, Class: person
# New object: ID 109, Class: person
# Object 109 (person) disappeared
# New object: ID 110, Class: person
# Object 110 (person) disappeared
# New object: ID 111, Class: person
# Object 111 (person) disappeared
#
# === Periodic Log ===
# Periodic log: 3 objects detected
# - ID 106: person, Confidence: 0.93, Center: (203, 303)
# - ID 107: person, Confidence: 0.73, Center: (479, 271)
# - ID 108: person, Confidence: 0.72, Center: (381, 414)
# New object: ID 112, Class: person
# Object 112 (person) disappeared
# New object: ID 113, Class: person
# Object 113 (person) disappeared
